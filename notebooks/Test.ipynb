# %%
from pycaret.anomaly import *
import pandas as pd
df = pd.read_csv('../transaction_anomalies_dataset.csv')
df.head()
# Out:
#   Transaction_ID  Transaction_Amount  Transaction_Volume  \
# 0            TX0         1024.835708                   3
# 1            TX1         1013.952065                   4
# 2            TX2          970.956093                   1
# 3            TX3         1040.822254                   2
# 4            TX4          998.777241                   1
#
#    Average_Transaction_Amount  Frequency_of_Transactions  \
# 0                  997.234714                         12
# 1                 1020.210306                          7
# 2                  989.496604                          5
# 3                  969.522480                         16
# 4                 1007.111026                          7
#
#    Time_Since_Last_Transaction Day_of_Week Time_of_Day  Age  Gender   Income  \
# 0                           29      Friday       06:00   36    Male  1436074
# 1                           22      Friday       01:00   41  Female   627069
# ...

# %%
setup(data=df,
      normalize=True,  # Standardisation des données
      ignore_features=["Transaction_ID"],  # Exclusion des métadonnées
      session_id=123,
      remove_multicollinearity=True,  # Réduction de la corrélation entre caractéristiques
      )  # Sélection automatique des features
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 setup(data=df,
#       2       normalize=True,  # Standardisation des données
#       3       ignore_features=["Transaction_ID"],  # Exclusion des métadonnées
#       4       session_id=123,
#       5       remove_multicollinearity=True,  # Réduction de la corrélation entre caractéristiques
#       6       )  # Sélection automatique des features
#
# ...

# %%
! pip install pycaret==3.0.4
